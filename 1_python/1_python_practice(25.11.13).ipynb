# %%
import platform
print(platform.python_version())
# Out:
# 3.13.9

# %%
# 문제
print(type(3.14))
print(type("3.14"))
print(type(True))
print(type("True"))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'str'>

# %%
# 문제
x = "15"
y = int(x) + 5
print(y)
# Out:
# 20

# %%
# 문제
print( 5 // 2 )
print( 5 % 2 )
print( 2 ** 3 )
print( 10 / 4 )
# Out:
# 2
# 1
# 8
# 2.5

# %%
# 문제
result = 10 + 2 * 3 ** 2
print(result)
# Out:
# 28

# %%
# 문제
a = 10
a += 3
a *= 2
print(a)
# Out:
# 26

# %%
# 문제
num = input("숫자를 입력해주세요:")
print(type(num))
# Out:
# <class 'str'>

# %%
# 문제
title = "interstellar"
year = 2014
print(f"영화 인터스텔라({title})는 {year}년에 개봉했다.")
# Out:
# 영화 인터스텔라(interstellar)는 2014년에 개봉했다.

# %%
# 문제
nums = [10, 20, 30, 40, 50]
print(nums[0])
print(nums[-1])
# Out:
# 10
# 50

# %%
# 문제
nums = [100, 200, 300, 400, 500, 600, 700]
print(nums[2:5])
# Out:
# [300, 400, 500]

# %%
# 문제
items = ["a", "b", "c", "d", "e"]
print(items[::-1])
# Out:
# ['e', 'd', 'c', 'b', 'a']

# %%
# 문제
movies = [" 인셉션", "인터스텔라", "어벤져스", "라라랜드", "기생충"]
movies[2:4] = "매트릭스", "타이타닉"
print(movies)
# Out:
# [' 인셉션', '인터스텔라', '매트릭스', '타이타닉', '기생충']

# %%
# 문제
fruits = ["apple", "banana", "cherry", "grape", "watermelon", "strawberry"]
del fruits[1:4]
print(fruits)
# Out:
# ['apple', 'watermelon', 'strawberry']

# %%
# 문제
friend1 = ["철수", "영희"]
friend2 = ["민수", "지훈"]
friend = friend1 + friend2
del friend[1]
friend.insert(0, "수진")
del friend[2]
print(friend[::-1])
# Out:
# ['지훈', '철수', '수진']
