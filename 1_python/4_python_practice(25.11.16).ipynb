# %%
# 문제1. 문자열 길이 구하기
text = input("문자를 입력하세요.")
text1 = len(text)
print(f"문자열의 길이는 {text1} 입니다.")
# Out:
# 문자열의 길이는 5 입니다.

# %%
# 문제2. 홀짝 판별
number = int(input("숫자를 입력하세요."))
labels = ["짝수", "홀수"]
print(f"해당 정수는 {labels[number % 2]} 입니다")
# Out:
# 해당 정수는 짝수 입니다

# %%
# 문제3. 리스트 슬라이싱
my_list = [5, 10, 15, 20, 25, 30]
list1 = my_list[1:4]
print(list1)
# Out:
# [10, 15, 20]

# %%
# 문제4. 문자열 분리
text = "10,20,30,40".split(",")
print(text)
# Out:
# ['10', '20', '30', '40']

# %%
# 문제5. 숫자로 변환
text = "10,20,30,40".split(",")
numb = [int(text[0]), int(text[1]), int(text[2]), int(text[3])]
print(numb)

numb1 = list(map(int, text))
print(numb1)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40]

# %%
# 문제6. 최대값 / 최소값
my_list = [12, 7, 19, 3, 15]
print(f"""최대값: {max(my_list)}
최소값: {min(my_list)}""")
# Out:
# 최대값: 19
# 최소값: 3

# %%
# 문제7. 금액 단위 변환
num = int(input("숫자를 입력하세요."))
print(f"입력한 숫자는 {num:,}원 입니다.")
# Out:
# 입력한 숫자는 123,456원 입니다.

# %%
# 문제8. 리스트 합계
my_list = [1, 2, 3, 4, 5]
num = my_list[0] + my_list[1] + my_list[2] + my_list[3] + my_list[4]
print(num)
# Out:
# 15

# %%
# 문제9. 리스트 변환
fruit = "Apple Banana Mango".split(" ")
print(fruit)
# Out:
# ['Apple', 'Banana', 'Mango']

# %%
# 문제10. 리스트 합치기
a = [1, 2, 3]
b = [4, 5]
c = a + b
print(c)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 문제11. 문자열 역순 출력
program = "Python"
program1 = program[::-1]
print(program1)
# Out:
# nohtyP

# %%
# 문제12. 리스트에서 짝수만 뽑기
my_numb = [1, 2, 3, 4, 5, 6, 7, 8]
numb = my_numb[1::2]
print(numb)
# Out:
# [2, 4, 6, 8]

# %%
# 문제13. 평균값 구하기
num1 = int(input("숫자1을 입력하세요."))
num2 = int(input("숫자2을 입력하세요."))
num3 = int(input("숫자3을 입력하세요."))
print(f"세 숫자의 평균은 {(num1 + num2 + num3) / 3}입니다.")
# Out:
# 세 숫자의 평균은 2.0입니다.

# %%
# 문제14. 대문자 / 소문자 변환
text = input("문자를 입력하세요.")
print(text.upper())
# Out:
# ABC

# %%
# 문제15. 리스트 값 교체
numbers = [10, 20, 30, 40]
numbers[1] = 200
print(numbers)
# Out:
# [10, 200, 30, 40]

# %%
# 문제16. 문자열 포함 여부
text = "hello world"
word = input("입력할 단어를 선택하세요.")
result = ["포함X", "포함O"]
print(result[word in text])
# Out:
# 포함O

# %%
# 문제17. 특정 인덱스 삭제
my_numb = [10, 20, 30, 40, 50]
del my_numb[2]
print(my_numb)
# Out:
# [10, 20, 40, 50]

# %%
# 문제18. 리스트 정렬
my_numb = [7, 2, 9, 1, 5]
my_numb.sort()
print(my_numb)
my_numb.sort(reverse=True)
print(my_numb)
# Out:
# [1, 2, 5, 7, 9]
# [9, 7, 5, 2, 1]

# %%
# 문제19. 문자열 숫자 합 구하기
number = "12345"
numb = [number[0], number[1], number[2], number[3], number[4]]
numb1 = int(numb[0]) + int(numb[1]) + int(numb[2]) + int(numb[3]) + int(numb[4])
print(numb1)
# Out:
# 15

# %%
# 문제20. 형 변환
numb = int("10")
print(str(numb))

numb1 = str("20")
print(int(numb1))
# Out:
# 10
# 20

# %%
# 문제1. 문자열을 입력받아 첫 글자만 대문자로 출력하라.
text = input("문자를 입력해주세요.")
print(text[0].upper() + text[1:])
# Out:
# Wdh

# %%
# 문제2. 문자열을 입력받아 마지막 글자만 출력하라.
text = input("문자를 입력해주세요.")
print(text[-1:])
# Out:
# h

# %%
# 문제3. "10, 20, 30, 40" 을 숫자 리스트 [10, 20, 30, 40] 으로 만들기
numb = "10,20,30,40".split(",")
my_numb = list(map(int, numb))
print(my_numb)
# Out:
# [10, 20, 30, 40]

# %%
# 문제4. 리스트 [5, 10, 15, 20, 25] 에서 가운데 값 (15)만 슬라이싱으로 뽑아라
my_numb = [5, 10, 15, 20, 25]
print(my_numb[2])
# Out:
# 15

# %%
# 문제5. 금액을 입력받아 "__원" 형태로 천 단위 콤마까지 붙여 출력하라.
money = int(input("숫자를 입력하세요."))
print(f"현재 금액은 {money:,}입니다.")
# Out:
# 현재 금액은 5,000,000 입니다.

# %%
# 문제6: 문자열을 입력받아 그 안에 "a" 가 포함되어 있으면 O, 아니면 X 출력
word = "a"
text = input("문자를 입력해주세요.")
result = ["x", "o"]
print(result[word in text])
# Out:
# o

# %%
# 문제7. 리스트 [1, 2, 3, 4, 5, 6] 에서 인덱스 2 ~ 4만 출력하라.
numb = [1, 2, 3, 4, 5, 6]
print(numb[2:5])
# Out:
# [3, 4, 5]

# %%
# 문제8. 문자열 "Python123"에서 숫자 부분만 분리하여 출력하기.
text = "Python123"
print(text[6:])
# Out:
# 123

# %%
# 문제9. 리스트 [10, 20, 30, 40]의 모든 값을 문자열로 변환하라.
numb = [10, 20, 30, 40]
str_numb = list(map(str, numb))
print(str_numb)
# Out:
# ['10', '20', '30', '40']

# %%
# 문제10. 숫자 3개 입력받아 리스트를 만들고, 그 리스트의 평균을 출력하라.
num1 = int(input("숫자1을 입력하세요."))
num2 = int(input("숫자2을 입력하세요."))
num3 = int(input("숫자3을 입력하세요."))
my_num = [num1, num2, num3]
print(f"세 숫자의 평균은 {(num1 + num2 + num3) / 3}입니다.")
# Out:
# 세 숫자의 평균은 2.0입니다.

# %%
# 문제11. 문자열을 입력받아 거꾸로 출력하라.
my_text = input("문자를 입력해주세요.")
print(my_text[::-1])
# Out:
# nohtyp

# %%
# 문제12. 문자열의 길이를 출력하고, 그 문자열의 첫 글자와 마지막 글자도 함께 출력하라.
my_text = input("문자를 입력해주세요.")
print(f"""문자의 길이: {len(my_text)}
문자열의 첫 글자: {my_text[0]}
문자열의 마지막 글자: {my_text[-1:]}""")
# Out:
# 문자의 길이: 6
# 문자열의 첫 글자: p
# 문자열의 마지막 글자: n

# %%
# 문제13. 리스트 [2, 4, 6, 8, 10]의 합을 반복문 없이 구하라.
my_numb = [2, 4, 6, 8, 10]
print(sum(my_numb))
# Out:
# 30

# %%
# 문제14. "hello world" 문자열서 공백 (" ")을 기준으로 단어를 나누어 리스트로 만들기
my_text = "hello world".split(" ")
print(my_text)
# Out:
# ['hello', 'world']

# %%
# 문제15. 정수를 입력받아 홀/짝 출력하라.
my_numb = int(input("숫자를 입력해주세요."))
labels = ["짝수", "홀수"]
print(f"해당 정수는 {labels[my_numb % 2]}입니다.")
# Out:
# 해당 정수는 홀수입니다.
